# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

from src.utils import metrics
from src.utils import data_loader as d
import random

SEED = 42
np.random.seed(SEED)
random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
islas_dfs = d.data_loader()
# Out:
# Fecha inicio: 2020-01-01 00:00:00
# Fecha fin: 2024-06-30 00:00:00
# Total number of days: 1642 days 00:00:00

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from sklearn.preprocessing import MinMaxScaler

# ======= 1. Data Loading and Preprocessing =======

# # Load data from CSV file (ensure your CSV has columns: "date" and "energy")
# data = pd.read_csv('energy_demand.csv', parse_dates=['date'])
# data.sort_values('date', inplace=True)

# Extract energy demand values and reshape for scaling
energy = islas_dfs['Tenerife']['OBS_VALUE'].values.reshape(-1,1) # data['energy'].values.reshape(-1, 1)

# Scale the data to [0,1] for easier training
scaler = MinMaxScaler()
energy_scaled = scaler.fit_transform(energy)

# ======= 2. Train-Validation-Test Split =======
train_size = 1460  # First 4 years for training/validation
val_size = int(0.2 * train_size)  # 20% of training data for validation
window_size = 30  # Window size for sequences

# Split into training, validation, and test sets
train_data = energy_scaled[:train_size - val_size]
val_data = energy_scaled[train_size - val_size:train_size]
test_data = energy_scaled[train_size - window_size:]

# Utility function: create input-output sequences using a sliding window
def create_sequences(data, window_size):
    sequences = []
    targets = []
    for i in range(len(data) - window_size):
        seq = data[i:i + window_size]
        target = data[i + window_size]
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Create sequences for training and validation
train_sequences, train_targets = create_sequences(train_data, window_size)
val_sequences, val_targets = create_sequences(val_data, window_size)

# Convert to PyTorch tensors
train_sequences = torch.tensor(train_sequences, dtype=torch.float32)
train_targets = torch.tensor(train_targets, dtype=torch.float32)
val_sequences = torch.tensor(val_sequences, dtype=torch.float32)
val_targets = torch.tensor(val_targets, dtype=torch.float32)

# ======= 3. Define the LSTM Model =======
class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=1):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)
    
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        
        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# ======= 4. Initial Training with Validation =======
model = LSTMModel()
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

num_epochs = 5000
train_losses, val_losses = [], []

for epoch in range(num_epochs):
    model.train()
    optimizer.zero_grad()
    output = model(train_sequences)
    train_loss = criterion(output, train_targets)
    train_loss.backward()
    optimizer.step()
    
    # Validation step
    model.eval()
    with torch.no_grad():
        val_output = model(val_sequences)
        val_loss = criterion(val_output, val_targets)
    
    train_losses.append(train_loss.item())
    val_losses.append(val_loss.item())

    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss.item():.4f}, Val Loss: {val_loss.item():.4f}')

# ======= 5. Plot Training vs Validation Loss =======
plt.figure(figsize=(8, 5))
plt.plot(train_losses, label='Train Loss', color='blue')
plt.plot(val_losses, label='Validation Loss', color='orange')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.title('Training vs Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch [10/5000], Train Loss: 0.0935, Val Loss: 0.2109
# Epoch [20/5000], Train Loss: 0.0223, Val Loss: 0.0312
# Epoch [30/5000], Train Loss: 0.0221, Val Loss: 0.0486
# Epoch [40/5000], Train Loss: 0.0232, Val Loss: 0.0571
# Epoch [50/5000], Train Loss: 0.0209, Val Loss: 0.0329
# Epoch [60/5000], Train Loss: 0.0194, Val Loss: 0.0355
# Epoch [70/5000], Train Loss: 0.0174, Val Loss: 0.0266
# Epoch [80/5000], Train Loss: 0.0140, Val Loss: 0.0150
# Epoch [90/5000], Train Loss: 0.0123, Val Loss: 0.0347
# Epoch [100/5000], Train Loss: 0.0115, Val Loss: 0.0162
# Epoch [110/5000], Train Loss: 0.0113, Val Loss: 0.0136
# Epoch [120/5000], Train Loss: 0.0110, Val Loss: 0.0147
# Epoch [130/5000], Train Loss: 0.0108, Val Loss: 0.0131
# Epoch [140/5000], Train Loss: 0.0106, Val Loss: 0.0125
# Epoch [150/5000], Train Loss: 0.0105, Val Loss: 0.0123
# Epoch [160/5000], Train Loss: 0.0104, Val Loss: 0.0123
# Epoch [170/5000], Train Loss: 0.0104, Val Loss: 0.0124
# Epoch [180/5000], Train Loss: 0.0104, Val Loss: 0.0125
# Epoch [190/5000], Train Loss: 0.0104, Val Loss: 0.0125
# Epoch [200/5000], Train Loss: 0.0103, Val Loss: 0.0125
# Epoch [210/5000], Train Loss: 0.0103, Val Loss: 0.0125
# Epoch [220/5000], Train Loss: 0.0103, Val Loss: 0.0125
# Epoch [230/5000], Train Loss: 0.0103, Val Loss: 0.0125
# Epoch [240/5000], Train Loss: 0.0103, Val Loss: 0.0124
# Epoch [250/5000], Train Loss: 0.0103, Val Loss: 0.0124
# Epoch [260/5000], Train Loss: 0.0103, Val Loss: 0.0124
# Epoch [270/5000], Train Loss: 0.0102, Val Loss: 0.0124
# Epoch [280/5000], Train Loss: 0.0102, Val Loss: 0.0124
# Epoch [290/5000], Train Loss: 0.0102, Val Loss: 0.0124
# Epoch [300/5000], Train Loss: 0.0102, Val Loss: 0.0123
# Epoch [310/5000], Train Loss: 0.0102, Val Loss: 0.0123
# Epoch [320/5000], Train Loss: 0.0102, Val Loss: 0.0123
# Epoch [330/5000], Train Loss: 0.0101, Val Loss: 0.0123
# Epoch [340/5000], Train Loss: 0.0101, Val Loss: 0.0122
# Epoch [350/5000], Train Loss: 0.0101, Val Loss: 0.0122
# Epoch [360/5000], Train Loss: 0.0101, Val Loss: 0.0122
# Epoch [370/5000], Train Loss: 0.0101, Val Loss: 0.0122
# Epoch [380/5000], Train Loss: 0.0100, Val Loss: 0.0121
# Epoch [390/5000], Train Loss: 0.0100, Val Loss: 0.0121
# Epoch [400/5000], Train Loss: 0.0100, Val Loss: 0.0121
# Epoch [410/5000], Train Loss: 0.0100, Val Loss: 0.0121
# Epoch [420/5000], Train Loss: 0.0099, Val Loss: 0.0120
# Epoch [430/5000], Train Loss: 0.0099, Val Loss: 0.0120
# Epoch [440/5000], Train Loss: 0.0099, Val Loss: 0.0120
# Epoch [450/5000], Train Loss: 0.0099, Val Loss: 0.0119
# Epoch [460/5000], Train Loss: 0.0098, Val Loss: 0.0119
# Epoch [470/5000], Train Loss: 0.0098, Val Loss: 0.0119
# Epoch [480/5000], Train Loss: 0.0098, Val Loss: 0.0118
# Epoch [490/5000], Train Loss: 0.0097, Val Loss: 0.0118
# Epoch [500/5000], Train Loss: 0.0097, Val Loss: 0.0117
# Epoch [510/5000], Train Loss: 0.0096, Val Loss: 0.0117
# Epoch [520/5000], Train Loss: 0.0096, Val Loss: 0.0116
# Epoch [530/5000], Train Loss: 0.0095, Val Loss: 0.0115
# Epoch [540/5000], Train Loss: 0.0095, Val Loss: 0.0115
# Epoch [550/5000], Train Loss: 0.0094, Val Loss: 0.0114
# Epoch [560/5000], Train Loss: 0.0093, Val Loss: 0.0112
# Epoch [570/5000], Train Loss: 0.0093, Val Loss: 0.0111
# Epoch [580/5000], Train Loss: 0.0092, Val Loss: 0.0110
# Epoch [590/5000], Train Loss: 0.0090, Val Loss: 0.0108
# Epoch [600/5000], Train Loss: 0.0089, Val Loss: 0.0106
# Epoch [610/5000], Train Loss: 0.0087, Val Loss: 0.0103
# Epoch [620/5000], Train Loss: 0.0083, Val Loss: 0.0098
# Epoch [630/5000], Train Loss: 0.0075, Val Loss: 0.0086
# Epoch [640/5000], Train Loss: 0.0065, Val Loss: 0.0101
# Epoch [650/5000], Train Loss: 0.0059, Val Loss: 0.0076
# Epoch [660/5000], Train Loss: 0.0055, Val Loss: 0.0078
# Epoch [670/5000], Train Loss: 0.0056, Val Loss: 0.0071
# Epoch [680/5000], Train Loss: 0.0054, Val Loss: 0.0077
# Epoch [690/5000], Train Loss: 0.0052, Val Loss: 0.0069
# Epoch [700/5000], Train Loss: 0.0051, Val Loss: 0.0068
# Epoch [710/5000], Train Loss: 0.0050, Val Loss: 0.0065
# Epoch [720/5000], Train Loss: 0.0048, Val Loss: 0.0064
# Epoch [730/5000], Train Loss: 0.0046, Val Loss: 0.0060
# Epoch [740/5000], Train Loss: 0.0043, Val Loss: 0.0055
# Epoch [750/5000], Train Loss: 0.0037, Val Loss: 0.0046
# Epoch [760/5000], Train Loss: 0.0031, Val Loss: 0.0044
# Epoch [770/5000], Train Loss: 0.0030, Val Loss: 0.0035
# Epoch [780/5000], Train Loss: 0.0030, Val Loss: 0.0038
# Epoch [790/5000], Train Loss: 0.0028, Val Loss: 0.0037
# Epoch [800/5000], Train Loss: 0.0027, Val Loss: 0.0032
# Epoch [810/5000], Train Loss: 0.0027, Val Loss: 0.0032
# Epoch [820/5000], Train Loss: 0.0027, Val Loss: 0.0032
# Epoch [830/5000], Train Loss: 0.0026, Val Loss: 0.0032
# Epoch [840/5000], Train Loss: 0.0026, Val Loss: 0.0032
# Epoch [850/5000], Train Loss: 0.0026, Val Loss: 0.0032
# Epoch [860/5000], Train Loss: 0.0026, Val Loss: 0.0032
# Epoch [870/5000], Train Loss: 0.0025, Val Loss: 0.0031
# Epoch [880/5000], Train Loss: 0.0025, Val Loss: 0.0031
# Epoch [890/5000], Train Loss: 0.0025, Val Loss: 0.0031
# Epoch [900/5000], Train Loss: 0.0025, Val Loss: 0.0031
# Epoch [910/5000], Train Loss: 0.0025, Val Loss: 0.0031
# Epoch [920/5000], Train Loss: 0.0025, Val Loss: 0.0031
# Epoch [930/5000], Train Loss: 0.0025, Val Loss: 0.0031
# Epoch [940/5000], Train Loss: 0.0027, Val Loss: 0.0040
# Epoch [950/5000], Train Loss: 0.0025, Val Loss: 0.0030
# Epoch [960/5000], Train Loss: 0.0024, Val Loss: 0.0033
# Epoch [970/5000], Train Loss: 0.0024, Val Loss: 0.0030
# Epoch [980/5000], Train Loss: 0.0024, Val Loss: 0.0031
# Epoch [990/5000], Train Loss: 0.0024, Val Loss: 0.0030
# Epoch [1000/5000], Train Loss: 0.0024, Val Loss: 0.0030
# Epoch [1010/5000], Train Loss: 0.0024, Val Loss: 0.0030
# Epoch [1020/5000], Train Loss: 0.0024, Val Loss: 0.0030
# Epoch [1030/5000], Train Loss: 0.0024, Val Loss: 0.0030
# Epoch [1040/5000], Train Loss: 0.0024, Val Loss: 0.0030
# Epoch [1050/5000], Train Loss: 0.0024, Val Loss: 0.0030
# Epoch [1060/5000], Train Loss: 0.0023, Val Loss: 0.0030
# Epoch [1070/5000], Train Loss: 0.0023, Val Loss: 0.0030
# Epoch [1080/5000], Train Loss: 0.0023, Val Loss: 0.0030
# Epoch [1090/5000], Train Loss: 0.0023, Val Loss: 0.0030
# Epoch [1100/5000], Train Loss: 0.0024, Val Loss: 0.0034
# Epoch [1110/5000], Train Loss: 0.0025, Val Loss: 0.0035
# Epoch [1120/5000], Train Loss: 0.0023, Val Loss: 0.0031
# Epoch [1130/5000], Train Loss: 0.0023, Val Loss: 0.0030
# Epoch [1140/5000], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1150/5000], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1160/5000], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1170/5000], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1180/5000], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1190/5000], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1200/5000], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1210/5000], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1220/5000], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1230/5000], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1240/5000], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1250/5000], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1260/5000], Train Loss: 0.0022, Val Loss: 0.0029
# Epoch [1270/5000], Train Loss: 0.0022, Val Loss: 0.0029
# Epoch [1280/5000], Train Loss: 0.0023, Val Loss: 0.0030
# Epoch [1290/5000], Train Loss: 0.0025, Val Loss: 0.0029
# Epoch [1300/5000], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1310/5000], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1320/5000], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1330/5000], Train Loss: 0.0022, Val Loss: 0.0029
# Epoch [1340/5000], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1350/5000], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1360/5000], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1370/5000], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1380/5000], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1390/5000], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1400/5000], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1410/5000], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1420/5000], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1430/5000], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1440/5000], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1450/5000], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1460/5000], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1470/5000], Train Loss: 0.0032, Val Loss: 0.0028
# Epoch [1480/5000], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch [1490/5000], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch [1500/5000], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch [1510/5000], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch [1520/5000], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch [1530/5000], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1540/5000], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1550/5000], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1560/5000], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch [1570/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1580/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1590/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1600/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1610/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1620/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1630/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1640/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1650/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1660/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1670/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1680/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1690/5000], Train Loss: 0.0021, Val Loss: 0.0028
# Epoch [1700/5000], Train Loss: 0.0022, Val Loss: 0.0047
# Epoch [1710/5000], Train Loss: 0.0024, Val Loss: 0.0027
# Epoch [1720/5000], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch [1730/5000], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch [1740/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1750/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1760/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1770/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1780/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1790/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1800/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1810/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1820/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1830/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1840/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1850/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1860/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1870/5000], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1880/5000], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1890/5000], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1900/5000], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1910/5000], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1920/5000], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1930/5000], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1940/5000], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1950/5000], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1960/5000], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1970/5000], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1980/5000], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1990/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2000/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2010/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2020/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2030/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2040/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2050/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2060/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2070/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2080/5000], Train Loss: 0.0021, Val Loss: 0.0028
# Epoch [2090/5000], Train Loss: 0.0024, Val Loss: 0.0036
# Epoch [2100/5000], Train Loss: 0.0021, Val Loss: 0.0030
# Epoch [2110/5000], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [2120/5000], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [2130/5000], Train Loss: 0.0020, Val Loss: 0.0027
# Epoch [2140/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2150/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2160/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2170/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2180/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2190/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2200/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2210/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2220/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2230/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2240/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2250/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2260/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2270/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2280/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2290/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2300/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2310/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2320/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2330/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2340/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2350/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2360/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2370/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2380/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2390/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2400/5000], Train Loss: 0.0020, Val Loss: 0.0027
# Epoch [2410/5000], Train Loss: 0.0020, Val Loss: 0.0027
# Epoch [2420/5000], Train Loss: 0.0019, Val Loss: 0.0027
# Epoch [2430/5000], Train Loss: 0.0019, Val Loss: 0.0027
# Epoch [2440/5000], Train Loss: 0.0019, Val Loss: 0.0027
# Epoch [2450/5000], Train Loss: 0.0019, Val Loss: 0.0027
# Epoch [2460/5000], Train Loss: 0.0019, Val Loss: 0.0027
# Epoch [2470/5000], Train Loss: 0.0035, Val Loss: 0.0036
# Epoch [2480/5000], Train Loss: 0.0023, Val Loss: 0.0037
# Epoch [2490/5000], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch [2500/5000], Train Loss: 0.0021, Val Loss: 0.0028
# Epoch [2510/5000], Train Loss: 0.0020, Val Loss: 0.0027
# Epoch [2520/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2530/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2540/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2550/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2560/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2570/5000], Train Loss: 0.0020, Val Loss: 0.0027
# Epoch [2580/5000], Train Loss: 0.0020, Val Loss: 0.0027
# Epoch [2590/5000], Train Loss: 0.0020, Val Loss: 0.0027
# Epoch [2600/5000], Train Loss: 0.0020, Val Loss: 0.0027
# Epoch [2610/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2620/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2630/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2640/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2650/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2660/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2670/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2680/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2690/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2700/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2710/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2720/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2730/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2740/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2750/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2760/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2770/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2780/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2790/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2800/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2810/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2820/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2830/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2840/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2850/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2860/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2870/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2880/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2890/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2900/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2910/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2920/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2930/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2940/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2950/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2960/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2970/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2980/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2990/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3000/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3010/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3020/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3030/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3040/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3050/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3060/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3070/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3080/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3090/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3100/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3110/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3120/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3130/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3140/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3150/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3160/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3170/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3180/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3190/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3200/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3210/5000], Train Loss: 0.0020, Val Loss: 0.0027
# Epoch [3220/5000], Train Loss: 0.0019, Val Loss: 0.0027
# Epoch [3230/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3240/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3250/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3260/5000], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch [3270/5000], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch [3280/5000], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch [3290/5000], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch [3300/5000], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch [3310/5000], Train Loss: 0.0020, Val Loss: 0.0028
# Epoch [3320/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3330/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3340/5000], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch [3350/5000], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch [3360/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3370/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3380/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3390/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3400/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3410/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3420/5000], Train Loss: 0.0020, Val Loss: 0.0029
# Epoch [3430/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3440/5000], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch [3450/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3460/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3470/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3480/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3490/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3500/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3510/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3520/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3530/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3540/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3550/5000], Train Loss: 0.0022, Val Loss: 0.0026
# Epoch [3560/5000], Train Loss: 0.0021, Val Loss: 0.0028
# Epoch [3570/5000], Train Loss: 0.0018, Val Loss: 0.0031
# Epoch [3580/5000], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3590/5000], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch [3600/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3610/5000], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch [3620/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3630/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3640/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3650/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3660/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3670/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3680/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3690/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3700/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3710/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3720/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3730/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3740/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3750/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3760/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3770/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3780/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [3790/5000], Train Loss: 0.0023, Val Loss: 0.0035
# Epoch [3800/5000], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [3810/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [3820/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3830/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3840/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [3850/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3860/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3870/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3880/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3890/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3900/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3910/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3920/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3930/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3940/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3950/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3960/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3970/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3980/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [3990/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4000/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4010/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4020/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4030/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4040/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4050/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4060/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4070/5000], Train Loss: 0.0018, Val Loss: 0.0029
# Epoch [4080/5000], Train Loss: 0.0024, Val Loss: 0.0030
# Epoch [4090/5000], Train Loss: 0.0021, Val Loss: 0.0028
# Epoch [4100/5000], Train Loss: 0.0019, Val Loss: 0.0028
# Epoch [4110/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4120/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [4130/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [4140/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4150/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4160/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4170/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4180/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4190/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4200/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4210/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4220/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4230/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4240/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4250/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4260/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4270/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4280/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4290/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4300/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4310/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4320/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4330/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4340/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4350/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4360/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4370/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4380/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4390/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4400/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4410/5000], Train Loss: 0.0019, Val Loss: 0.0031
# Epoch [4420/5000], Train Loss: 0.0019, Val Loss: 0.0031
# Epoch [4430/5000], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [4440/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4450/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4460/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4470/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4480/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4490/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4500/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4510/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4520/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4530/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4540/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4550/5000], Train Loss: 0.0019, Val Loss: 0.0029
# Epoch [4560/5000], Train Loss: 0.0018, Val Loss: 0.0029
# Epoch [4570/5000], Train Loss: 0.0018, Val Loss: 0.0028
# Epoch [4580/5000], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch [4590/5000], Train Loss: 0.0017, Val Loss: 0.0026
# Epoch [4600/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4610/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4620/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4630/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4640/5000], Train Loss: 0.0017, Val Loss: 0.0029
# Epoch [4650/5000], Train Loss: 0.0017, Val Loss: 0.0029
# Epoch [4660/5000], Train Loss: 0.0017, Val Loss: 0.0029
# Epoch [4670/5000], Train Loss: 0.0017, Val Loss: 0.0029
# Epoch [4680/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4690/5000], Train Loss: 0.0017, Val Loss: 0.0030
# Epoch [4700/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4710/5000], Train Loss: 0.0017, Val Loss: 0.0029
# Epoch [4720/5000], Train Loss: 0.0017, Val Loss: 0.0029
# Epoch [4730/5000], Train Loss: 0.0017, Val Loss: 0.0029
# Epoch [4740/5000], Train Loss: 0.0017, Val Loss: 0.0030
# Epoch [4750/5000], Train Loss: 0.0017, Val Loss: 0.0030
# Epoch [4760/5000], Train Loss: 0.0017, Val Loss: 0.0029
# Epoch [4770/5000], Train Loss: 0.0017, Val Loss: 0.0029
# Epoch [4780/5000], Train Loss: 0.0017, Val Loss: 0.0029
# Epoch [4790/5000], Train Loss: 0.0017, Val Loss: 0.0030
# Epoch [4800/5000], Train Loss: 0.0017, Val Loss: 0.0029
# Epoch [4810/5000], Train Loss: 0.0017, Val Loss: 0.0029
# Epoch [4820/5000], Train Loss: 0.0017, Val Loss: 0.0029
# Epoch [4830/5000], Train Loss: 0.0017, Val Loss: 0.0029
# Epoch [4840/5000], Train Loss: 0.0016, Val Loss: 0.0029
# Epoch [4850/5000], Train Loss: 0.0017, Val Loss: 0.0029
# Epoch [4860/5000], Train Loss: 0.0016, Val Loss: 0.0029
# Epoch [4870/5000], Train Loss: 0.0016, Val Loss: 0.0029
# Epoch [4880/5000], Train Loss: 0.0017, Val Loss: 0.0029
# Epoch [4890/5000], Train Loss: 0.0016, Val Loss: 0.0030
# Epoch [4900/5000], Train Loss: 0.0017, Val Loss: 0.0030
# Epoch [4910/5000], Train Loss: 0.0017, Val Loss: 0.0030
# Epoch [4920/5000], Train Loss: 0.0017, Val Loss: 0.0033
# Epoch [4930/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4940/5000], Train Loss: 0.0017, Val Loss: 0.0028
# Epoch [4950/5000], Train Loss: 0.0016, Val Loss: 0.0031
# Epoch [4960/5000], Train Loss: 0.0016, Val Loss: 0.0030
# Epoch [4970/5000], Train Loss: 0.0016, Val Loss: 0.0030
# Epoch [4980/5000], Train Loss: 0.0016, Val Loss: 0.0030
# Epoch [4990/5000], Train Loss: 0.0016, Val Loss: 0.0029
# Epoch [5000/5000], Train Loss: 0.0016, Val Loss: 0.0030

# %%
# ======= 6. Online Prediction and Model Update =======
test_sequences, test_targets = create_sequences(test_data, window_size)
test_sequences = torch.tensor(test_sequences, dtype=torch.float32)
test_targets = torch.tensor(test_targets, dtype=torch.float32)

online_predictions = []
actual_values = []

online_optimizer = optim.Adam(model.parameters(), lr=0.0001)

for i in range(len(test_sequences)):
    x = test_sequences[i].unsqueeze(0)
    
    model.eval()
    with torch.no_grad():
        pred = model(x)
    online_predictions.append(pred.item())
    actual_values.append(test_targets[i].item())

    # Online learning step
    model.train()
    online_optimizer.zero_grad()
    pred_online = model(x)
    loss_online = criterion(pred_online, test_targets[i].unsqueeze(0))
    loss_online.backward()
    online_optimizer.step()

# Inverse transform
online_predictions_inv = scaler.inverse_transform(np.array(online_predictions).reshape(-1, 1)).flatten()
actual_values_inv = scaler.inverse_transform(np.array(actual_values).reshape(-1, 1)).flatten()

metrics_result = metrics.all_metrics(actual_values_inv, online_predictions_inv)
print("Evaluation Metrics:")
for metric, value in metrics_result.items():
    print(f"{metric}: {value:.4f}")
# Out:
# Evaluation Metrics:
# MAE: 164.7169
# MSE: 66271.3289
# RMSE: 257.4322
# R2: 0.6163
# MAPE: 0.0192
# sMAPE: 0.0191

# %%
fig, ax = plt.subplots()
line_pred, = ax.plot([], [], label='Prediction', color='blue')
line_act, = ax.plot([], [], label='Actual', color='red')
ax.legend()
ax.set_xlabel('Day')
ax.set_ylabel('Energy Demand')
ax.set_xlim(0, len(online_predictions_inv))
ax.set_ylim(min(min(online_predictions_inv), min(actual_values_inv)) * 0.9, 
            max(max(online_predictions_inv), max(actual_values_inv)) * 1.1)

def init():
    line_pred.set_data([], [])
    line_act.set_data([], [])
    return line_pred, line_act

def animate(i):
    x = np.arange(i + 1)
    y_pred = online_predictions_inv[:i + 1]
    y_act = actual_values_inv[:i + 1]
    line_pred.set_data(x, y_pred)
    line_act.set_data(x, y_act)
    return line_pred, line_act

ani = animation.FuncAnimation(fig, animate, frames=len(online_predictions_inv),
                              init_func=init, interval=50, blit=True)

ani.save('online_prediction.mp4', writer='ffmpeg')

plt.show()
