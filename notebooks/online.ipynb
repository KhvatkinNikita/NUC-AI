# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

from src.utils import metrics
from src.utils import data_loader as d
import random

SEED = 42
np.random.seed(SEED)
random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
islas_dfs = d.data_loader()
# Out:
# Fecha inicio: 2020-01-01 00:00:00
# Fecha fin: 2024-06-30 00:00:00
# Total number of days: 1642 days 00:00:00

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from sklearn.preprocessing import MinMaxScaler

# ======= 1. Data Loading and Preprocessing =======

# # Load data from CSV file (ensure your CSV has columns: "date" and "energy")
# data = pd.read_csv('energy_demand.csv', parse_dates=['date'])
# data.sort_values('date', inplace=True)

# Extract energy demand values and reshape for scaling
energy = islas_dfs['Tenerife']['OBS_VALUE'].values.reshape(-1,1) # data['energy'].values.reshape(-1, 1)

# Scale the data to [0,1] for easier training
scaler = MinMaxScaler()
energy_scaled = scaler.fit_transform(energy)

# ======= 2. Train-Validation-Test Split =======
train_size = 1460  # First 4 years for training/validation
val_size = int(0.2 * train_size)  # 20% of training data for validation
window_size = 30  # Window size for sequences

# Split into training, validation, and test sets
train_data = energy_scaled[:train_size - val_size]
val_data = energy_scaled[train_size - val_size:train_size]
test_data = energy_scaled[train_size - window_size:]

# Utility function: create input-output sequences using a sliding window
def create_sequences(data, window_size):
    sequences = []
    targets = []
    for i in range(len(data) - window_size):
        seq = data[i:i + window_size]
        target = data[i + window_size]
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Create sequences for training and validation
train_sequences, train_targets = create_sequences(train_data, window_size)
val_sequences, val_targets = create_sequences(val_data, window_size)

# Convert to PyTorch tensors
train_sequences = torch.tensor(train_sequences, dtype=torch.float32)
train_targets = torch.tensor(train_targets, dtype=torch.float32)
val_sequences = torch.tensor(val_sequences, dtype=torch.float32)
val_targets = torch.tensor(val_targets, dtype=torch.float32)

# ======= 3. Define the LSTM Model =======
class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=1):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)
    
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        
        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# ======= 4. Initial Training with Validation =======
model = LSTMModel()
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

num_epochs = 3555 # best without overfitting
train_losses, val_losses = [], []

for epoch in range(num_epochs):
    model.train()
    optimizer.zero_grad()
    output = model(train_sequences)
    train_loss = criterion(output, train_targets)
    train_loss.backward()
    optimizer.step()
    
    # Validation step
    model.eval()
    with torch.no_grad():
        val_output = model(val_sequences)
        val_loss = criterion(val_output, val_targets)
    
    train_losses.append(train_loss.item())
    val_losses.append(val_loss.item())

    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss.item():.4f}, Val Loss: {val_loss.item():.4f}')

# ======= 5. Plot Training vs Validation Loss =======
plt.figure(figsize=(8, 5))
plt.plot(train_losses, label='Train Loss', color='blue')
plt.plot(val_losses, label='Validation Loss', color='orange')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.title('Training vs Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch [10/3555], Train Loss: 0.0935, Val Loss: 0.2109
# Epoch [20/3555], Train Loss: 0.0223, Val Loss: 0.0312
# Epoch [30/3555], Train Loss: 0.0221, Val Loss: 0.0486
# Epoch [40/3555], Train Loss: 0.0232, Val Loss: 0.0571
# Epoch [50/3555], Train Loss: 0.0209, Val Loss: 0.0329
# Epoch [60/3555], Train Loss: 0.0194, Val Loss: 0.0355
# Epoch [70/3555], Train Loss: 0.0174, Val Loss: 0.0266
# Epoch [80/3555], Train Loss: 0.0140, Val Loss: 0.0150
# Epoch [90/3555], Train Loss: 0.0123, Val Loss: 0.0347
# Epoch [100/3555], Train Loss: 0.0115, Val Loss: 0.0162
# Epoch [110/3555], Train Loss: 0.0113, Val Loss: 0.0136
# Epoch [120/3555], Train Loss: 0.0110, Val Loss: 0.0147
# Epoch [130/3555], Train Loss: 0.0108, Val Loss: 0.0131
# Epoch [140/3555], Train Loss: 0.0106, Val Loss: 0.0125
# Epoch [150/3555], Train Loss: 0.0105, Val Loss: 0.0123
# Epoch [160/3555], Train Loss: 0.0104, Val Loss: 0.0123
# Epoch [170/3555], Train Loss: 0.0104, Val Loss: 0.0124
# Epoch [180/3555], Train Loss: 0.0104, Val Loss: 0.0125
# Epoch [190/3555], Train Loss: 0.0104, Val Loss: 0.0125
# Epoch [200/3555], Train Loss: 0.0103, Val Loss: 0.0125
# Epoch [210/3555], Train Loss: 0.0103, Val Loss: 0.0125
# Epoch [220/3555], Train Loss: 0.0103, Val Loss: 0.0125
# Epoch [230/3555], Train Loss: 0.0103, Val Loss: 0.0125
# Epoch [240/3555], Train Loss: 0.0103, Val Loss: 0.0124
# Epoch [250/3555], Train Loss: 0.0103, Val Loss: 0.0124
# Epoch [260/3555], Train Loss: 0.0103, Val Loss: 0.0124
# Epoch [270/3555], Train Loss: 0.0102, Val Loss: 0.0124
# Epoch [280/3555], Train Loss: 0.0102, Val Loss: 0.0124
# Epoch [290/3555], Train Loss: 0.0102, Val Loss: 0.0124
# Epoch [300/3555], Train Loss: 0.0102, Val Loss: 0.0123
# Epoch [310/3555], Train Loss: 0.0102, Val Loss: 0.0123
# Epoch [320/3555], Train Loss: 0.0102, Val Loss: 0.0123
# Epoch [330/3555], Train Loss: 0.0101, Val Loss: 0.0123
# Epoch [340/3555], Train Loss: 0.0101, Val Loss: 0.0122
# Epoch [350/3555], Train Loss: 0.0101, Val Loss: 0.0122
# Epoch [360/3555], Train Loss: 0.0101, Val Loss: 0.0122
# Epoch [370/3555], Train Loss: 0.0101, Val Loss: 0.0122
# Epoch [380/3555], Train Loss: 0.0100, Val Loss: 0.0121
# Epoch [390/3555], Train Loss: 0.0100, Val Loss: 0.0121
# Epoch [400/3555], Train Loss: 0.0100, Val Loss: 0.0121
# Epoch [410/3555], Train Loss: 0.0100, Val Loss: 0.0121
# Epoch [420/3555], Train Loss: 0.0099, Val Loss: 0.0120
# Epoch [430/3555], Train Loss: 0.0099, Val Loss: 0.0120
# Epoch [440/3555], Train Loss: 0.0099, Val Loss: 0.0120
# Epoch [450/3555], Train Loss: 0.0099, Val Loss: 0.0119
# Epoch [460/3555], Train Loss: 0.0098, Val Loss: 0.0119
# Epoch [470/3555], Train Loss: 0.0098, Val Loss: 0.0119
# Epoch [480/3555], Train Loss: 0.0098, Val Loss: 0.0118
# Epoch [490/3555], Train Loss: 0.0097, Val Loss: 0.0118
# Epoch [500/3555], Train Loss: 0.0097, Val Loss: 0.0117
# Epoch [510/3555], Train Loss: 0.0096, Val Loss: 0.0117
# Epoch [520/3555], Train Loss: 0.0096, Val Loss: 0.0116
# Epoch [530/3555], Train Loss: 0.0095, Val Loss: 0.0115
# Epoch [540/3555], Train Loss: 0.0095, Val Loss: 0.0115
# Epoch [550/3555], Train Loss: 0.0094, Val Loss: 0.0114
# Epoch [560/3555], Train Loss: 0.0093, Val Loss: 0.0112
# Epoch [570/3555], Train Loss: 0.0093, Val Loss: 0.0111
# Epoch [580/3555], Train Loss: 0.0092, Val Loss: 0.0110
# Epoch [590/3555], Train Loss: 0.0090, Val Loss: 0.0108
# Epoch [600/3555], Train Loss: 0.0089, Val Loss: 0.0106
# Epoch [610/3555], Train Loss: 0.0087, Val Loss: 0.0103
# Epoch [620/3555], Train Loss: 0.0083, Val Loss: 0.0098
# Epoch [630/3555], Train Loss: 0.0075, Val Loss: 0.0086
# Epoch [640/3555], Train Loss: 0.0065, Val Loss: 0.0101
# Epoch [650/3555], Train Loss: 0.0059, Val Loss: 0.0076
# Epoch [660/3555], Train Loss: 0.0055, Val Loss: 0.0078
# Epoch [670/3555], Train Loss: 0.0056, Val Loss: 0.0071
# Epoch [680/3555], Train Loss: 0.0054, Val Loss: 0.0077
# Epoch [690/3555], Train Loss: 0.0052, Val Loss: 0.0069
# Epoch [700/3555], Train Loss: 0.0051, Val Loss: 0.0068
# Epoch [710/3555], Train Loss: 0.0050, Val Loss: 0.0065
# Epoch [720/3555], Train Loss: 0.0048, Val Loss: 0.0064
# Epoch [730/3555], Train Loss: 0.0046, Val Loss: 0.0060
# Epoch [740/3555], Train Loss: 0.0043, Val Loss: 0.0055
# Epoch [750/3555], Train Loss: 0.0037, Val Loss: 0.0046
# Epoch [760/3555], Train Loss: 0.0031, Val Loss: 0.0044
# Epoch [770/3555], Train Loss: 0.0030, Val Loss: 0.0035
# Epoch [780/3555], Train Loss: 0.0030, Val Loss: 0.0038
# Epoch [790/3555], Train Loss: 0.0028, Val Loss: 0.0037
# Epoch [800/3555], Train Loss: 0.0027, Val Loss: 0.0032
# Epoch [810/3555], Train Loss: 0.0027, Val Loss: 0.0032
# Epoch [820/3555], Train Loss: 0.0027, Val Loss: 0.0032
# Epoch [830/3555], Train Loss: 0.0026, Val Loss: 0.0032
# Epoch [840/3555], Train Loss: 0.0026, Val Loss: 0.0032
# Epoch [850/3555], Train Loss: 0.0026, Val Loss: 0.0032
# Epoch [860/3555], Train Loss: 0.0026, Val Loss: 0.0032
# Epoch [870/3555], Train Loss: 0.0025, Val Loss: 0.0031
# Epoch [880/3555], Train Loss: 0.0025, Val Loss: 0.0031
# Epoch [890/3555], Train Loss: 0.0025, Val Loss: 0.0031
# Epoch [900/3555], Train Loss: 0.0025, Val Loss: 0.0031
# Epoch [910/3555], Train Loss: 0.0025, Val Loss: 0.0031
# Epoch [920/3555], Train Loss: 0.0025, Val Loss: 0.0031
# Epoch [930/3555], Train Loss: 0.0025, Val Loss: 0.0031
# Epoch [940/3555], Train Loss: 0.0027, Val Loss: 0.0040
# Epoch [950/3555], Train Loss: 0.0025, Val Loss: 0.0030
# Epoch [960/3555], Train Loss: 0.0024, Val Loss: 0.0033
# Epoch [970/3555], Train Loss: 0.0024, Val Loss: 0.0030
# Epoch [980/3555], Train Loss: 0.0024, Val Loss: 0.0031
# Epoch [990/3555], Train Loss: 0.0024, Val Loss: 0.0030
# Epoch [1000/3555], Train Loss: 0.0024, Val Loss: 0.0030
# Epoch [1010/3555], Train Loss: 0.0024, Val Loss: 0.0030
# Epoch [1020/3555], Train Loss: 0.0024, Val Loss: 0.0030
# Epoch [1030/3555], Train Loss: 0.0024, Val Loss: 0.0030
# Epoch [1040/3555], Train Loss: 0.0024, Val Loss: 0.0030
# Epoch [1050/3555], Train Loss: 0.0024, Val Loss: 0.0030
# Epoch [1060/3555], Train Loss: 0.0023, Val Loss: 0.0030
# Epoch [1070/3555], Train Loss: 0.0023, Val Loss: 0.0030
# Epoch [1080/3555], Train Loss: 0.0023, Val Loss: 0.0030
# Epoch [1090/3555], Train Loss: 0.0023, Val Loss: 0.0030
# Epoch [1100/3555], Train Loss: 0.0024, Val Loss: 0.0034
# Epoch [1110/3555], Train Loss: 0.0025, Val Loss: 0.0035
# Epoch [1120/3555], Train Loss: 0.0023, Val Loss: 0.0031
# Epoch [1130/3555], Train Loss: 0.0023, Val Loss: 0.0030
# Epoch [1140/3555], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1150/3555], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1160/3555], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1170/3555], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1180/3555], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1190/3555], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1200/3555], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1210/3555], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1220/3555], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1230/3555], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1240/3555], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1250/3555], Train Loss: 0.0023, Val Loss: 0.0029
# Epoch [1260/3555], Train Loss: 0.0022, Val Loss: 0.0029
# Epoch [1270/3555], Train Loss: 0.0022, Val Loss: 0.0029
# Epoch [1280/3555], Train Loss: 0.0023, Val Loss: 0.0030
# Epoch [1290/3555], Train Loss: 0.0025, Val Loss: 0.0029
# Epoch [1300/3555], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1310/3555], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1320/3555], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1330/3555], Train Loss: 0.0022, Val Loss: 0.0029
# Epoch [1340/3555], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1350/3555], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1360/3555], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1370/3555], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1380/3555], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1390/3555], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1400/3555], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1410/3555], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1420/3555], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1430/3555], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1440/3555], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1450/3555], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1460/3555], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1470/3555], Train Loss: 0.0032, Val Loss: 0.0028
# Epoch [1480/3555], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch [1490/3555], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch [1500/3555], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch [1510/3555], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch [1520/3555], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch [1530/3555], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1540/3555], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1550/3555], Train Loss: 0.0022, Val Loss: 0.0028
# Epoch [1560/3555], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch [1570/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1580/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1590/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1600/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1610/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1620/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1630/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1640/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1650/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1660/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1670/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1680/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1690/3555], Train Loss: 0.0021, Val Loss: 0.0028
# Epoch [1700/3555], Train Loss: 0.0022, Val Loss: 0.0047
# Epoch [1710/3555], Train Loss: 0.0024, Val Loss: 0.0027
# Epoch [1720/3555], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch [1730/3555], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch [1740/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1750/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1760/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1770/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1780/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1790/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1800/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1810/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1820/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1830/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1840/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1850/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1860/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [1870/3555], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1880/3555], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1890/3555], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1900/3555], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1910/3555], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1920/3555], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1930/3555], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1940/3555], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1950/3555], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1960/3555], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1970/3555], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1980/3555], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [1990/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2000/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2010/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2020/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2030/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2040/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2050/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2060/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2070/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2080/3555], Train Loss: 0.0021, Val Loss: 0.0028
# Epoch [2090/3555], Train Loss: 0.0024, Val Loss: 0.0036
# Epoch [2100/3555], Train Loss: 0.0021, Val Loss: 0.0030
# Epoch [2110/3555], Train Loss: 0.0021, Val Loss: 0.0026
# Epoch [2120/3555], Train Loss: 0.0021, Val Loss: 0.0027
# Epoch [2130/3555], Train Loss: 0.0020, Val Loss: 0.0027
# Epoch [2140/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2150/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2160/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2170/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2180/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2190/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2200/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2210/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2220/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2230/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2240/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2250/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2260/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2270/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2280/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2290/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2300/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2310/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2320/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2330/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2340/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2350/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2360/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2370/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2380/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2390/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2400/3555], Train Loss: 0.0020, Val Loss: 0.0027
# Epoch [2410/3555], Train Loss: 0.0020, Val Loss: 0.0027
# Epoch [2420/3555], Train Loss: 0.0019, Val Loss: 0.0027
# Epoch [2430/3555], Train Loss: 0.0019, Val Loss: 0.0027
# Epoch [2440/3555], Train Loss: 0.0019, Val Loss: 0.0027
# Epoch [2450/3555], Train Loss: 0.0019, Val Loss: 0.0027
# Epoch [2460/3555], Train Loss: 0.0019, Val Loss: 0.0027
# Epoch [2470/3555], Train Loss: 0.0035, Val Loss: 0.0036
# Epoch [2480/3555], Train Loss: 0.0023, Val Loss: 0.0037
# Epoch [2490/3555], Train Loss: 0.0022, Val Loss: 0.0027
# Epoch [2500/3555], Train Loss: 0.0021, Val Loss: 0.0028
# Epoch [2510/3555], Train Loss: 0.0020, Val Loss: 0.0027
# Epoch [2520/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2530/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2540/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2550/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2560/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2570/3555], Train Loss: 0.0020, Val Loss: 0.0027
# Epoch [2580/3555], Train Loss: 0.0020, Val Loss: 0.0027
# Epoch [2590/3555], Train Loss: 0.0020, Val Loss: 0.0027
# Epoch [2600/3555], Train Loss: 0.0020, Val Loss: 0.0027
# Epoch [2610/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2620/3555], Train Loss: 0.0020, Val Loss: 0.0026
# Epoch [2630/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2640/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2650/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2660/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2670/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2680/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2690/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2700/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2710/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2720/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2730/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2740/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2750/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2760/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2770/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2780/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2790/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2800/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2810/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2820/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2830/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2840/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2850/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2860/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2870/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2880/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2890/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2900/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2910/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2920/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2930/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2940/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2950/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2960/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2970/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2980/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [2990/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3000/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3010/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3020/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3030/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3040/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3050/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3060/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3070/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3080/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3090/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3100/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3110/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3120/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3130/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3140/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3150/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3160/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3170/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3180/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3190/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3200/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3210/3555], Train Loss: 0.0020, Val Loss: 0.0027
# Epoch [3220/3555], Train Loss: 0.0019, Val Loss: 0.0027
# Epoch [3230/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3240/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3250/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3260/3555], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch [3270/3555], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch [3280/3555], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch [3290/3555], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch [3300/3555], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch [3310/3555], Train Loss: 0.0020, Val Loss: 0.0028
# Epoch [3320/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3330/3555], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3340/3555], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch [3350/3555], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch [3360/3555], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3370/3555], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3380/3555], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3390/3555], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3400/3555], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3410/3555], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3420/3555], Train Loss: 0.0020, Val Loss: 0.0029
# Epoch [3430/3555], Train Loss: 0.0019, Val Loss: 0.0026
# Epoch [3440/3555], Train Loss: 0.0018, Val Loss: 0.0026
# Epoch [3450/3555], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3460/3555], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3470/3555], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3480/3555], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3490/3555], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3500/3555], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3510/3555], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3520/3555], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3530/3555], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3540/3555], Train Loss: 0.0018, Val Loss: 0.0027
# Epoch [3550/3555], Train Loss: 0.0022, Val Loss: 0.0026

# %%
np.where(val_losses == np.array(val_losses).min())
# Out:
# (array([3554]),)

# %%
# ======= 6. Online Prediction and Model Update =======
test_sequences, test_targets = create_sequences(test_data, window_size)
test_sequences = torch.tensor(test_sequences, dtype=torch.float32)
test_targets = torch.tensor(test_targets, dtype=torch.float32)

online_predictions = []
actual_values = []

online_optimizer = optim.Adam(model.parameters(), lr=0.0001)

for i in range(len(test_sequences)):
    x = test_sequences[i].unsqueeze(0)
    
    model.eval()
    with torch.no_grad():
        pred = model(x)
    online_predictions.append(pred.item())
    actual_values.append(test_targets[i].item())

    # Online learning step
    model.train()
    online_optimizer.zero_grad()
    pred_online = model(x)
    loss_online = criterion(pred_online, test_targets[i].unsqueeze(0))
    loss_online.backward()
    online_optimizer.step()

# Inverse transform
online_predictions_inv = scaler.inverse_transform(np.array(online_predictions).reshape(-1, 1)).flatten()
actual_values_inv = scaler.inverse_transform(np.array(actual_values).reshape(-1, 1)).flatten()

metrics_result = metrics.all_metrics(actual_values_inv, online_predictions_inv)
print("Evaluation Metrics:")
for metric, value in metrics_result.items():
    print(f"{metric}: {value:.4f}")
# Out:
# Evaluation Metrics:
# MAE: 154.2488
# MSE: 61733.2208
# RMSE: 248.4617
# R2: 0.6425
# MAPE: 0.0179
# sMAPE: 0.0178

# %%
fig, ax = plt.subplots()
line_pred, = ax.plot([], [], label='Prediction', color='blue')
line_act, = ax.plot([], [], label='Actual', color='red')
ax.legend()
ax.set_xlabel('Day')
ax.set_ylabel('Energy Demand')
ax.set_xlim(0, len(online_predictions_inv))
ax.set_ylim(min(min(online_predictions_inv), min(actual_values_inv)) * 0.9, 
            max(max(online_predictions_inv), max(actual_values_inv)) * 1.1)

def init():
    line_pred.set_data([], [])
    line_act.set_data([], [])
    return line_pred, line_act

def animate(i):
    x = np.arange(i + 1)
    y_pred = online_predictions_inv[:i + 1]
    y_act = actual_values_inv[:i + 1]
    line_pred.set_data(x, y_pred)
    line_act.set_data(x, y_act)
    return line_pred, line_act

ani = animation.FuncAnimation(fig, animate, frames=len(online_predictions_inv),
                              init_func=init, interval=50, blit=True)

ani.save('online_prediction.mp4', writer='ffmpeg')

plt.show()
