# %%
# Imports
import random

import numpy as np

import matplotlib.pyplot as plt
import matplotlib.animation as animation

import torch
import torch.nn as nn
import torch.optim as optim

from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import MinMaxScaler

from src.utils import metrics
from src.utils import data_loader as d
from src.utils import models
from src.utils import sliding_window as s

SEED = 42
np.random.seed(SEED)
random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Load Data
islas_dfs = d.local_data_loader(verbose=False)
# Data transform

results = {}
metricas = []
windows = np.arange(5,20)
islas = ['Tenerife', 'Gran Canaria', 'Lanzarote', 'Fuerteventura', 'La Palma', 'La Gomera', 'El Hierro']

for isla in islas:
    for window in windows:

        print(f'ISLA: {isla}, WINDOW = {window}')

        # Extract demand value
        demand = islas_dfs[isla]['OBS_VALUE'].values.reshape(-1,1) # data['energy'].values.reshape(-1, 1)

        # Training and validation
        train_size = 1460  # First 4 years for training/validation
        val_size = int(0.2 * train_size)  # 20% of training data for validation
        window_size = window 

        # Split into training, validation, and test sets
        train_data = demand[:train_size - val_size]
        val_data = demand[train_size - val_size:train_size]
        test_data = demand[train_size - window_size:]

        # Sliding window sequences for training and validation
        train_sequences, train_targets = s.create_sequences(train_data, window_size)
        val_sequences, val_targets = s.create_sequences(val_data, window_size)

        # Convert to PyTorch tensors
        train_sequences = torch.tensor(train_sequences, dtype=torch.float32)
        train_targets = torch.tensor(train_targets, dtype=torch.float32)
        val_sequences = torch.tensor(val_sequences, dtype=torch.float32)
        val_targets = torch.tensor(val_targets, dtype=torch.float32)
        # Model training and validation
        from nbeats_pytorch.model import NBeatsNet 

        model = NBeatsNet(
            stack_types=("generic", "generic"),
            forecast_length=1,
            backcast_length=window_size,
            hidden_layer_units=128
        )

        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=1e-3)

        train_losses, val_losses = [], []
        best_val_loss = float('inf')
        stopping_counter = 0
        early_stopping = True

        num_epochs = 20_000 
        early_stopping_patience = 1_000

        for epoch in range(num_epochs):
            # Training step
            model.train()
            optimizer.zero_grad()
            _, output = model(train_sequences)
            train_loss = criterion(output, train_targets)
            train_loss.backward()
            optimizer.step()

            # Validation step
            model.eval()
            with torch.no_grad():
                _, val_output = model(val_sequences)
                val_loss = criterion(val_output, val_targets)

            train_losses.append(train_loss.item())
            val_losses.append(val_loss.item())
            if val_loss.item() < best_val_loss:
                best_val_loss = val_loss.item()
                stopping_counter = 0
            else:
                stopping_counter += 1

            if early_stopping and stopping_counter >= early_stopping_patience:
                # print("Early stopping triggered!")
                break

            # if (epoch + 1) % 500 == 0:
                # print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss.item():.4f}, Val Loss: {val_loss.item():.4f}\n')


        # Prediction
        test_sequences, test_targets = s.create_sequences(test_data, window_size)
        test_sequences = torch.tensor(test_sequences, dtype=torch.float32)
        test_targets = torch.tensor(test_targets, dtype=torch.float32)

        # Initialize lists for storing predictions
        online_predictions = []
        actual_values = []

        # Define online optimizer and loss function
        online_optimizer = optim.Adam(model.parameters(), lr=1e-6)
        criterion = nn.MSELoss()

        # ======= 9. Online Prediction and Evaluation =======
        for i in range(len(test_sequences)):
            x = test_sequences[i].unsqueeze(0)

            # Model inference
            model.eval()
            with torch.no_grad():
                pred = model(x)[1]  # Extract the forecast output
            online_predictions.append(pred.item())
            actual_values.append(test_targets[i].item())

            # Online learning step
            model.train()
            online_optimizer.zero_grad()
            pred_online = model(x)[1]  # Extract forecast again for training
            loss_online = criterion(pred_online, test_targets[i].unsqueeze(0))
            loss_online.backward()
            online_optimizer.step()


        metrics_result = metrics.all_metrics(actual_values, online_predictions)
        # print("Evaluation Metrics:")
        # print(f'R2: {metrics_result['R2']}')
        # for metric, value in metrics_result.items():
        #     print(f"{metric}: {value:.4f}")
        # print('\n')

        # Animation
        test_dates = islas_dfs[isla]['TIME_PERIOD_CODE'].values.reshape(-1,1)
        metricas.append(metrics_result['R2'])
        results[isla] = metricas
# Out:
# ISLA: Tenerife, WINDOW = 5
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @13037075296
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @13056644144
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @13056649088
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @6083895680
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @13056648224
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @13056647792
# ISLA: Tenerife, WINDOW = 6
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @13186183008
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @13049120576
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @13375984160
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @13188312400
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @13389237616
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @13389238096
# ISLA: Tenerife, WINDOW = 7
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @13034081120
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @13056649952
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @13389144064
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @13055653936
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @13056648608
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @13056648176
# ISLA: Tenerife, WINDOW = 8
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @13037075296
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @13388857024
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @13188312400
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @13383983344
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @13389237520
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @13389237952
# ISLA: Tenerife, WINDOW = 9
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @13045275088
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @13056644144
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @13056650192
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @13387746144
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @13056648128
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @13056647696
# ISLA: Tenerife, WINDOW = 10
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @13382883264
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @13370215408
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @13188312400
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @13186183008
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @13389237184
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @13389238336
# ISLA: Tenerife, WINDOW = 11
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @13387570912
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @13056647264
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @13056648704
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @13389149488
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @13056647888
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @13056647504
# ISLA: Tenerife, WINDOW = 12
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @13370405232
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @13385344032
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @13369470384
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @13056447392
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @13389237184
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @13389238336
# ISLA: Tenerife, WINDOW = 13
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @6084374176
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @13056650336
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @13056644240
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @13376115136
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @13056648368
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @13056647936
# ISLA: Tenerife, WINDOW = 14
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @13388750944
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @13370225344
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @13049856848
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @13388857024
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @13389237184
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @13389238336
# ISLA: Tenerife, WINDOW = 15
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @13037075296
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @13056650480
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @13056644144
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @13387746144
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @13056648368
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @13056647936
# ISLA: Tenerife, WINDOW = 16
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @13182757072
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @13375984160
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @13388303008
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @13188307168
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @13389237184
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @13389238336
# ISLA: Tenerife, WINDOW = 17
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @13369677760
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @13045275088
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @13056650336
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @13388128832
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @13056648368
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @13056647936
# ISLA: Tenerife, WINDOW = 18
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @13369675264
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @13370215408
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @13056447392
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @13385342880
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @13389237088
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @13389238192
# ISLA: Tenerife, WINDOW = 19
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @13369677760
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @13387755360
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @13056650480
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @13389142432
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @13056648368
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @13056647936
# ISLA: Gran Canaria, WINDOW = 5
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @13049856848
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @13056447392
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @13385341728
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @13388857024
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @13389237520
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @13389237952
# ISLA: Gran Canaria, WINDOW = 6
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @13375788560
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @13389142432
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @13056649952
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @6084374176
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @13056648368
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @13056647936
# ISLA: Gran Canaria, WINDOW = 7
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @13370215408
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @13383978976
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @13388857024
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @13370224960
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @13389238096
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @13389237760
# ISLA: Gran Canaria, WINDOW = 8
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @13049462960
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @13056652256
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @13056648944
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @13182757072
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @13056647696
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @13056647648
# ISLA: Gran Canaria, WINDOW = 9
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @13370405232
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @13383982720
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @13370215408
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @13369470384
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @13389238096
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @13389237760
# ISLA: Gran Canaria, WINDOW = 10
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @6084374176
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @13387754496
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @13056644528
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @13056447392
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @13056647696
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @13056647648
# ISLA: Gran Canaria, WINDOW = 11
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @13037075296
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @13388854624
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @13370224960
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @13385342880
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @13389238096
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @13389237760
# ISLA: Gran Canaria, WINDOW = 12
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @13049462960
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @13056650192
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @13056649040
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @13389142432
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @13056647408
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @13056647504
# ISLA: Gran Canaria, WINDOW = 13
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @13182757072
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @13383983344
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @13385341728
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @13374953888
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @13389238000
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @13389238192
# ISLA: Gran Canaria, WINDOW = 14
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @13371128576
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @13388750944
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @13056642320
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @13387755360
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @13056647408
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @13056647504
# ISLA: Gran Canaria, WINDOW = 15
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @13037075296
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @13383979888
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @13375788560
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @13369675264
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @13389237232
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @13389237472
# ISLA: Gran Canaria, WINDOW = 16
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @13388750944
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @13056647264
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @13056650480
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @6084374176
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @13056647936
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @13056648128
# ISLA: Gran Canaria, WINDOW = 17
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @13387754928
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @13367707840
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @13371128576
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @13370224960
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @13389237232
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @13389237472
# ISLA: Gran Canaria, WINDOW = 18
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @5897641024
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @13056447392
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @13056644528
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @13370405232
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @13056647696
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @13056647648
# ISLA: Gran Canaria, WINDOW = 19
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @13388303008
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @13383978976
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @13056644240
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @13385341728
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @13389237952
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @13389239200
# ISLA: Lanzarote, WINDOW = 5
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @13188307168
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @13056642320
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @13056649952
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @13387755360
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @13056647984
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @6084374176
# ISLA: Lanzarote, WINDOW = 6
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @13037075296
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @13385342880
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @13056648608
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @13370225344
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @13389239440
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @13389237808
# ISLA: Lanzarote, WINDOW = 7
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @13370405232
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @13056649088
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @13056652256
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @13389142432
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @13056648080
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @13389238048
# ISLA: Lanzarote, WINDOW = 8
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @13387564288
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @13370225344
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @13056644144
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @13383979552
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @13389237904
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @13389237616
# ISLA: Lanzarote, WINDOW = 9
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @13387754496
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @13056648752
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @13056649952
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @13387746144
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @13056647984
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @13389239824
# ISLA: Lanzarote, WINDOW = 10
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @13037075296
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @13383983344
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @13056648176
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @13385341728
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @13389237520
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @13389237712
# ISLA: Lanzarote, WINDOW = 11
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @6084374176
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @13056647456
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @13056647504
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @13389144112
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @13387754496
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @13389237280
# ISLA: Lanzarote, WINDOW = 12
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @13049462960
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @13385344032
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @13056648464
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @13056840608
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @13389237040
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @13389237952
# ISLA: Lanzarote, WINDOW = 13
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @13387746144
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @13056647840
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @13056649088
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @13387754496
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @13056647648
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @13389237088
# ISLA: Lanzarote, WINDOW = 14
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @13037075296
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @13387564288
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @13056648992
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @13383982720
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @13389237232
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @13389237904
# ISLA: Lanzarote, WINDOW = 15
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @13049462960
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @13056648560
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @13056647744
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @13056647840
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @13367707840
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @13389240064
# ISLA: Lanzarote, WINDOW = 16
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @13037075296
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @13056836384
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @13389142432
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @13385344032
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @13389237040
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @13389237952
# ISLA: Lanzarote, WINDOW = 17
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @13389149488
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @13056648560
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @13056647744
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @13387754496
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @13389238240
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @13389239344
# ISLA: Lanzarote, WINDOW = 18
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @5897641024
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @13056840608
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @13056648992
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @13388854624
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @13389237904
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @13389238144
# ISLA: Lanzarote, WINDOW = 19
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @13389149488
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @13056648560
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @13056647744
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @13387755360
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @13389238240
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @13389239344
# ISLA: Fuerteventura, WINDOW = 5
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @13056452960
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @13389143776
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @13056644144
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @13056836384
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @13389239248
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @13389238096
# ISLA: Fuerteventura, WINDOW = 6
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @13387746144
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @13056647264
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @13056648848
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @13387755360
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @13389238048
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @13389238672
# ISLA: Fuerteventura, WINDOW = 7
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @6084374176
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @13370225344
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @13056648800
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @13385341728
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @13389239440
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @13389237808
# ISLA: Fuerteventura, WINDOW = 8
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @5897641024
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @13056647744
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @13056648224
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @13056648704
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @13389239920
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @13389238528
# ISLA: Fuerteventura, WINDOW = 9
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @13056836432
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @13056644144
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @13056648272
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @13389143776
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @13389239440
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @13389237808
# ISLA: Fuerteventura, WINDOW = 10
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @13387746144
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @13056647744
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @13056648224
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @13182757072
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @13389238672
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @13389240400
# ISLA: Fuerteventura, WINDOW = 11
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @13383979552
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @13056836336
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @13056647936
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @13385341728
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @13389239440
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @13389237808
# ISLA: Fuerteventura, WINDOW = 12
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @13387746144
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @13056647456
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @13056648704
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @13056647600
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @13389239872
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @13389239200
# ISLA: Fuerteventura, WINDOW = 13
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @13375984160
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @13056648608
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @13056648512
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @13389143248
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @13389237904
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @13389237136
# ISLA: Fuerteventura, WINDOW = 14
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @13056648560
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @13056647648
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @13056648176
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @13056642320
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @13389239872
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @13389239200
# ISLA: Fuerteventura, WINDOW = 15
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @13056836384
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @13056648992
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @13056647696
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @13385342880
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @13389237184
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @13389238336
# ISLA: Fuerteventura, WINDOW = 16
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @13182757072
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @13056650192
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @13056647408
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @13056648368
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @13389237424
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @13389240160
# ISLA: Fuerteventura, WINDOW = 17
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @13388854624
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @13056648992
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @13056647696
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @13389143248
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @13389239440
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @13389237808
# ISLA: Fuerteventura, WINDOW = 18
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @13056647648
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @13056648848
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @13056647792
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @13056647744
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @13389240400
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @13389240304
# ISLA: Fuerteventura, WINDOW = 19
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @13388854624
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @13056648608
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @13056647840
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @13056836384
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @13389238144
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @13389237568
# ISLA: La Palma, WINDOW = 5
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @13056647648
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @13056642320
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @13056648368
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @13056648176
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @13389240160
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @13389239824
# ISLA: La Palma, WINDOW = 6
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @13056644144
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @13056648992
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @13370225344
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @13056644336
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @13389239392
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @13389240448
# ISLA: La Palma, WINDOW = 7
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @13056452960
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @13056649040
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @13056647600
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @13056650336
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @13389240304
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @13389240592
# ISLA: La Palma, WINDOW = 8
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @13056836384
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @13056648512
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @13389237184
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @13389143776
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @13389238624
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @13389240688
# ISLA: La Palma, WINDOW = 9
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @13388854624
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @13056648752
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @13056836432
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @13056649088
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @13389239824
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @13389240976
# ISLA: La Palma, WINDOW = 10
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @13056654704
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @13056644336
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @13389237184
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @13056652256
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @13389240736
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @13389240400
# ISLA: La Palma, WINDOW = 11
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @5897641024
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @13056647600
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @13389237472
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @13056649040
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @13389240880
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @13389241168

# %%
for isla in islas:
    print(f'\n\nBest window for {isla}: {windows[int(np.where(results['Tenerife'] == np.max(results['Tenerife']))[0])]}')
