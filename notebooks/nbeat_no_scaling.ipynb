# %%
# Imports
import random

import numpy as np

import matplotlib.pyplot as plt
import matplotlib.animation as animation

import torch
import torch.nn as nn
import torch.optim as optim

from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import MinMaxScaler

from src.utils import metrics
from src.utils import data_loader as d
from src.utils import models
from src.utils import sliding_window as s

SEED = 42
np.random.seed(SEED)
random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Load Data
islas_dfs = d.local_data_loader(verbose=False)
# Data transform

results = {}

windows = np.arange(5,20)
islas = ['Tenerife', 'Gran Canaria', 'Lanzarote', 'Fuerteventura', 'La Palma', 'La Gomera', 'El Hierro']

for isla in islas:
    metricas = []
    for window in windows:

        print(f'ISLA: {isla}, WINDOW = {window}')

        # Extract demand value
        demand = islas_dfs[isla]['OBS_VALUE'].values.reshape(-1,1) # data['energy'].values.reshape(-1, 1)

        # Training and validation
        train_size = 1460  # First 4 years for training/validation
        val_size = int(0.2 * train_size)  # 20% of training data for validation
        window_size = window 

        # Split into training, validation, and test sets
        train_data = demand[:train_size - val_size]
        val_data = demand[train_size - val_size:train_size]
        test_data = demand[train_size - window_size:]

        # Sliding window sequences for training and validation
        train_sequences, train_targets = s.create_sequences(train_data, window_size)
        val_sequences, val_targets = s.create_sequences(val_data, window_size)

        # Convert to PyTorch tensors
        train_sequences = torch.tensor(train_sequences, dtype=torch.float32)
        train_targets = torch.tensor(train_targets, dtype=torch.float32)
        val_sequences = torch.tensor(val_sequences, dtype=torch.float32)
        val_targets = torch.tensor(val_targets, dtype=torch.float32)
        # Model training and validation
        from nbeats_pytorch.model import NBeatsNet 

        model = NBeatsNet(
            stack_types=("generic", "generic"),
            forecast_length=1,
            backcast_length=window_size,
            hidden_layer_units=128
        )

        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=1e-3)

        train_losses, val_losses = [], []
        best_val_loss = float('inf')
        stopping_counter = 0
        early_stopping = True

        num_epochs = 20_000 
        early_stopping_patience = 1_000

        for epoch in range(num_epochs):
            # Training step
            model.train()
            optimizer.zero_grad()
            _, output = model(train_sequences)
            train_loss = criterion(output, train_targets)
            train_loss.backward()
            optimizer.step()

            # Validation step
            model.eval()
            with torch.no_grad():
                _, val_output = model(val_sequences)
                val_loss = criterion(val_output, val_targets)

            train_losses.append(train_loss.item())
            val_losses.append(val_loss.item())
            if val_loss.item() < best_val_loss:
                best_val_loss = val_loss.item()
                stopping_counter = 0
            else:
                stopping_counter += 1

            if early_stopping and stopping_counter >= early_stopping_patience:
                # print("Early stopping triggered!")
                break

            # if (epoch + 1) % 500 == 0:
                # print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss.item():.4f}, Val Loss: {val_loss.item():.4f}\n')


        # Prediction
        test_sequences, test_targets = s.create_sequences(test_data, window_size)
        test_sequences = torch.tensor(test_sequences, dtype=torch.float32)
        test_targets = torch.tensor(test_targets, dtype=torch.float32)

        # Initialize lists for storing predictions
        online_predictions = []
        actual_values = []

        # Define online optimizer and loss function
        online_optimizer = optim.Adam(model.parameters(), lr=1e-6)
        criterion = nn.MSELoss()

        # ======= 9. Online Prediction and Evaluation =======
        for i in range(len(test_sequences)):
            x = test_sequences[i].unsqueeze(0)

            # Model inference
            model.eval()
            with torch.no_grad():
                pred = model(x)[1]  # Extract the forecast output
            online_predictions.append(pred.item())
            actual_values.append(test_targets[i].item())

            # Online learning step
            model.train()
            online_optimizer.zero_grad()
            pred_online = model(x)[1]  # Extract forecast again for training
            loss_online = criterion(pred_online, test_targets[i].unsqueeze(0))
            loss_online.backward()
            online_optimizer.step()


        metrics_result = metrics.all_metrics(actual_values, online_predictions)
        print("Evaluation Metrics:")
        print(f"R2: {metrics_result['R2']}")
        for metric, value in metrics_result.items():
            print(f"{metric}: {value:.4f}")
        print('\n')

        # Animation
        test_dates = islas_dfs[isla]['TIME_PERIOD_CODE'].values.reshape(-1,1)
        metricas.append(metrics_result['R2'])
        results[isla] = metricas
# Out:
# ISLA: Tenerife, WINDOW = 5
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @132354132901584
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @132354137605712
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @132353881930448
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @132353952340240
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @132353881790992
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @132353881788944
# Evaluation Metrics:
# R2: 0.6381877200105999
# MAE: 129.2124
# MSE: 62483.3676
# RMSE: 249.9667
# R2: 0.6382
# MAPE: 0.0152
# sMAPE: 0.0152
#
#
# ISLA: Tenerife, WINDOW = 6
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @132353876009168
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @132353856957712
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @132353857025744
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @132353725879312
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @132353725918288
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @132353725919952
# Evaluation Metrics:
# R2: 0.5261845753163719
# MAE: 171.7985
# MSE: 81825.8113
# RMSE: 286.0521
# R2: 0.5262
# MAPE: 0.0201
# sMAPE: 0.0201
#
#
# ISLA: Tenerife, WINDOW = 7
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @132354135372944
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @132353881794192
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @132353725910224
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @132353725921552
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @132353725922704
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @132353725922192
# Evaluation Metrics:
# R2: 0.7662231877061362
# MAE: 124.7185
# MSE: 40372.2132
# RMSE: 200.9284
# R2: 0.7662
# MAPE: 0.0146
# sMAPE: 0.0145
#
#
# ISLA: Tenerife, WINDOW = 8
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @132353725877776
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @132353725889232
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @132353725920208
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @132353881795408
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @132353881794128
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @132353726041104
# Evaluation Metrics:
# R2: 0.7861764190095405
# MAE: 113.8602
# MSE: 36926.3791
# RMSE: 192.1624
# R2: 0.7862
# MAPE: 0.0133
# sMAPE: 0.0132
#
#
# ISLA: Tenerife, WINDOW = 9
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @132353881790416
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @132353865097936
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @132353725915536
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @132353725919760
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @132353725922256
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @132353725922896
# Evaluation Metrics:
# R2: 0.7933476147656017
# MAE: 105.4670
# MSE: 35687.9456
# RMSE: 188.9125
# R2: 0.7933
# MAPE: 0.0123
# sMAPE: 0.0123
#
#
# ISLA: Tenerife, WINDOW = 10
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @132353881790736
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @132354048778576
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @132353725912784
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @132353725910288
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @132353725920400
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @132353726041296
# Evaluation Metrics:
# R2: 0.6900377708444503
# MAE: 147.4988
# MSE: 53529.0950
# RMSE: 231.3636
# R2: 0.6900
# MAPE: 0.0171
# sMAPE: 0.0171
#
#
# ISLA: Tenerife, WINDOW = 11
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @132353857102416
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @132353881915792
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @132353725878096
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @132353725888464
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @132353725883024
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @132353726038096
# Evaluation Metrics:
# R2: 0.7496834112174859
# MAE: 131.1785
# MSE: 43228.5588
# RMSE: 207.9148
# R2: 0.7497
# MAPE: 0.0152
# sMAPE: 0.0152
#
#
# ISLA: Tenerife, WINDOW = 12
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @132353881930448
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @132353725890000
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @132353725908496
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @132353725910544
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @132353725916432
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @132353726043472
# Evaluation Metrics:
# R2: 0.7721903694708345
# MAE: 114.3546
# MSE: 39341.7075
# RMSE: 198.3474
# R2: 0.7722
# MAPE: 0.0134
# sMAPE: 0.0133
#
#
# ISLA: Tenerife, WINDOW = 13
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @132353727896336
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @132353862318736
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @132353725888464
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @132353725883792
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @132353726038096
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @132353726044304
# Evaluation Metrics:
# R2: 0.7229999651214642
# MAE: 130.0850
# MSE: 47836.6710
# RMSE: 218.7160
# R2: 0.7230
# MAPE: 0.0152
# sMAPE: 0.0150
#
#
# ISLA: Tenerife, WINDOW = 14
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @132353727898192
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @132353865097936
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @132353725890000
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @132353725885264
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @132353726041744
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @132353726043280
# Evaluation Metrics:
# R2: 0.7022678196286865
# MAE: 138.8504
# MSE: 51417.0201
# RMSE: 226.7532
# R2: 0.7023
# MAPE: 0.0161
# sMAPE: 0.0161
#
#
# ISLA: Tenerife, WINDOW = 15
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @132353881930448
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @132353727898320
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @132353725908688
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @132353726042832
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @132353726045072
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @132353726045456
# Evaluation Metrics:
# R2: 0.7102986332338421
# MAE: 134.8466
# MSE: 50030.1344
# RMSE: 223.6742
# R2: 0.7103
# MAPE: 0.0157
# sMAPE: 0.0156
#
#
# ISLA: Tenerife, WINDOW = 16
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @132353857076304
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @132353725890000
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @132353727895504
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @132353726040656
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @132353726041808
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @132353726043024
# Evaluation Metrics:
# R2: 0.7561494869541148
# MAE: 114.4933
# MSE: 42111.8964
# RMSE: 205.2118
# R2: 0.7561
# MAPE: 0.0134
# sMAPE: 0.0133
#
#
# ISLA: Tenerife, WINDOW = 17
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @132354137605712
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @132353865097936
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @132353725874640
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @132353726039504
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @132353726038480
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @132353726046864
# Evaluation Metrics:
# R2: 0.7290566799353173
# MAE: 123.8662
# MSE: 46790.7034
# RMSE: 216.3116
# R2: 0.7291
# MAPE: 0.0145
# sMAPE: 0.0143
#
#
# ISLA: Tenerife, WINDOW = 18
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @132353881930448
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @132353881790736
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @132353725881232
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @132353726043600
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @132353726043536
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @132353726047696
# Evaluation Metrics:
# R2: 0.7358513983948803
# MAE: 121.9284
# MSE: 45617.2858
# RMSE: 213.5820
# R2: 0.7359
# MAPE: 0.0142
# sMAPE: 0.0141
#
#
# ISLA: Tenerife, WINDOW = 19
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @132353857013136
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @132353725889232
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @132353726038352
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @132353726043664
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @132353726038672
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @132353726043088
# Evaluation Metrics:
# R2: 0.7349407870916127
# MAE: 121.7371
# MSE: 45774.5443
# RMSE: 213.9499
# R2: 0.7349
# MAPE: 0.0142
# sMAPE: 0.0141
#
#
# ISLA: Gran Canaria, WINDOW = 5
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @132353727902928
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @132353725908368
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @132353725884048
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @132353726040208
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @132353726041104
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @132353726047504
# Evaluation Metrics:
# R2: 0.7346818253750715
# MAE: 136.9389
# MSE: 48104.7573
# RMSE: 219.3280
# R2: 0.7347
# MAPE: 0.0168
# sMAPE: 0.0165
#
#
# ISLA: Gran Canaria, WINDOW = 6
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @132353881790736
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @132353857128080
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @132353726038096
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @132353726044304
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @132353726045328
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @132353726046032
# Evaluation Metrics:
# R2: 0.7607381527435529
# MAE: 124.1051
# MSE: 43380.4925
# RMSE: 208.2798
# R2: 0.7607
# MAPE: 0.0152
# sMAPE: 0.0150
#
#
# ISLA: Gran Canaria, WINDOW = 7
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @132353727902928
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @132353727894352
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @132353726041936
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @132353726043472
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @132353726043792
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @132353726047632
# Evaluation Metrics:
# R2: 0.774793562157141
# MAE: 121.4197
# MSE: 40832.1105
# RMSE: 202.0696
# R2: 0.7748
# MAPE: 0.0148
# sMAPE: 0.0147
#
#
# ISLA: Gran Canaria, WINDOW = 8
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @132353857013136
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @132353725908496
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @132353726044496
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @132353726046160
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @132353726048144
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @132353726049168
# Evaluation Metrics:
# R2: 0.7017618512006887
# MAE: 139.2517
# MSE: 54073.4677
# RMSE: 232.5370
# R2: 0.7018
# MAPE: 0.0170
# sMAPE: 0.0168
#
#
# ISLA: Gran Canaria, WINDOW = 9
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @132353857076304
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @132353952340240
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @132353726038928
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @132353726043280
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @132353726045968
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @132353726050000
# Evaluation Metrics:
# R2: 0.7784581505403984
# MAE: 134.3183
# MSE: 40167.6851
# RMSE: 200.4188
# R2: 0.7785
# MAPE: 0.0162
# sMAPE: 0.0161
#
#
# ISLA: Gran Canaria, WINDOW = 10
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @132353857102416
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @132353857013136
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @132353726046096
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @132353726045328
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @132353726046032
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @132353726049616
# Evaluation Metrics:
# R2: 0.7477155392736718
# MAE: 123.1014
# MSE: 45741.6186
# RMSE: 213.8729
# R2: 0.7477
# MAPE: 0.0149
# sMAPE: 0.0149
#
#
# ISLA: Gran Canaria, WINDOW = 11
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @132354137605712
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @132353952340240
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @132353726040208
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @132353726041104
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @132353726047504
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @132353726048976
# Evaluation Metrics:
# R2: 0.8003848160025321
# MAE: 110.7978
# MSE: 36192.1681
# RMSE: 190.2424
# R2: 0.8004
# MAPE: 0.0135
# sMAPE: 0.0134
#
#
# ISLA: Gran Canaria, WINDOW = 12
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @132353857076304
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @132353725913360
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @132353726043728
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @132353726040016
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @132353726047248
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @132353726049424
# Evaluation Metrics:
# R2: 0.7295880716030114
# MAE: 139.8069
# MSE: 49028.3042
# RMSE: 221.4234
# R2: 0.7296
# MAPE: 0.0170
# sMAPE: 0.0169
#
#
# ISLA: Gran Canaria, WINDOW = 13
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @132353857102416
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @132353725877776
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @132353726045712
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @132353726043472
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @132353726043792
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @132353726047632
# Evaluation Metrics:
# R2: 0.7556455970260556
# MAE: 129.9247
# MSE: 44303.8222
# RMSE: 210.4847
# R2: 0.7556
# MAPE: 0.0158
# sMAPE: 0.0157
#
#
# ISLA: Gran Canaria, WINDOW = 14
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @132353727902928
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @132354137605712
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @132353726048272
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @132353726049296
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @132353726049552
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @132353726046480
# Evaluation Metrics:
# R2: 0.7580491149224575
# MAE: 128.1652
# MSE: 43868.0411
# RMSE: 209.4470
# R2: 0.7580
# MAPE: 0.0155
# sMAPE: 0.0155
#
#
# ISLA: Gran Canaria, WINDOW = 15
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @132353727904848
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @132353725877776
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @132353726045968
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @132353726047120
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @132353726048848
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @132353726051152
# Evaluation Metrics:
# R2: 0.7521478449605865
# MAE: 128.3499
# MSE: 44937.9986
# RMSE: 211.9858
# R2: 0.7521
# MAPE: 0.0155
# sMAPE: 0.0155
#
#
# ISLA: Gran Canaria, WINDOW = 16
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @132353857102416
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @132354048778576
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @132353726048272
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @132353726049296
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @132353726049552
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @132353726046480
# Evaluation Metrics:
# R2: 0.5380039283431207
# MAE: 215.2426
# MSE: 83764.3668
# RMSE: 289.4207
# R2: 0.5380
# MAPE: 0.0262
# sMAPE: 0.0260
#
#
# ISLA: Gran Canaria, WINDOW = 17
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @132353857013136
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @132353725915472
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @132353726038928
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @132353726043792
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @132353726047632
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @132353726051344
# Evaluation Metrics:
# R2: 0.7391732618825664
# MAE: 125.8708
# MSE: 47290.4163
# RMSE: 217.4636
# R2: 0.7392
# MAPE: 0.0154
# sMAPE: 0.0152
#
#
# ISLA: Gran Canaria, WINDOW = 18
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @132353727904848
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @132353727891088
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @132353726043664
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @132353726038672
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @132353726043088
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @132353726048656
# Evaluation Metrics:
# R2: 0.684181392877627
# MAE: 155.2033
# MSE: 57260.9753
# RMSE: 239.2927
# R2: 0.6842
# MAPE: 0.0187
# sMAPE: 0.0187
#
#
# ISLA: Gran Canaria, WINDOW = 19
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @132353727902928
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @132353857102416
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @132353726040592
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @132353726043408
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @132353726048784
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @132353726044240
# Evaluation Metrics:
# R2: 0.6785862017402751
# MAE: 155.6832
# MSE: 58275.4377
# RMSE: 241.4031
# R2: 0.6786
# MAPE: 0.0188
# sMAPE: 0.0188
#
#
# ISLA: Lanzarote, WINDOW = 5
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @132353727904848
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @132353727898320
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @132353726048080
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @132353726049488
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @132353726050384
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @132353726048400
# Evaluation Metrics:
# R2: 0.5693194607906948
# MAE: 27.6041
# MSE: 1505.9772
# RMSE: 38.8069
# R2: 0.5693
# MAPE: 0.0124
# sMAPE: 0.0125
#
#
# ISLA: Lanzarote, WINDOW = 6
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @132353952340240
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @132353725909904
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @132353726042896
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @132353726040720
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @132353726049104
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @132353726043216
# Evaluation Metrics:
# R2: 0.5534752734321811
# MAE: 28.7022
# MSE: 1561.3802
# RMSE: 39.5143
# R2: 0.5535
# MAPE: 0.0130
# sMAPE: 0.0130
#
#
# ISLA: Lanzarote, WINDOW = 7
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @132353857102416
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @132353857128080
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @132353726046992
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @132353726041168
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @132353726038480
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @132353726040656
# Evaluation Metrics:
# R2: 0.6429008238574824
# MAE: 24.7296
# MSE: 1248.6824
# RMSE: 35.3367
# R2: 0.6429
# MAPE: 0.0112
# sMAPE: 0.0112
#
#
# ISLA: Lanzarote, WINDOW = 8
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @132353727902928
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @132353725908944
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @132353726040464
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @132353726045584
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @132353726040208
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @132353726047056
# Evaluation Metrics:
# R2: 0.6706684451607332
# MAE: 21.9115
# MSE: 1151.5863
# RMSE: 33.9350
# R2: 0.6707
# MAPE: 0.0099
# sMAPE: 0.0099
#
#
# ISLA: Lanzarote, WINDOW = 9
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @132353725875792
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @132353725880592
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @132353726046160
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @132353726042320
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @132353726045328
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @132353726046032
# Evaluation Metrics:
# R2: 0.6869522546478543
# MAE: 22.5315
# MSE: 1094.6461
# RMSE: 33.0854
# R2: 0.6870
# MAPE: 0.0102
# sMAPE: 0.0102
#
#
# ISLA: Lanzarote, WINDOW = 10
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @132353857128080
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @132353726040912
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @132353726044368
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @132353726048720
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @132353726040784
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @132353726050448
# Evaluation Metrics:
# R2: 0.6828005037706594
# MAE: 23.2020
# MSE: 1109.1637
# RMSE: 33.3041
# R2: 0.6828
# MAPE: 0.0105
# sMAPE: 0.0105
#
#
# ISLA: Lanzarote, WINDOW = 11
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @132353952340240
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @132353725908944
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @132353726049296
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @132353726049552
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @132353726046480
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @132353726051280
# Evaluation Metrics:
# R2: 0.6953673038865513
# MAE: 21.5467
# MSE: 1065.2209
# RMSE: 32.6377
# R2: 0.6954
# MAPE: 0.0097
# sMAPE: 0.0097
#
#
# ISLA: Lanzarote, WINDOW = 12
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @132353881516560
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @132353725875600
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @132353726040976
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @132353726047184
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @132353726048592
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @132353726049040
# Evaluation Metrics:
# R2: 0.6592024447600362
# MAE: 23.8271
# MSE: 1191.6799
# RMSE: 34.5207
# R2: 0.6592
# MAPE: 0.0108
# sMAPE: 0.0107
#
#
# ISLA: Lanzarote, WINDOW = 13
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @132353725889232
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @132353725880592
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @132353726050896
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @132353726052624
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @132353726042768
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @132353726046800
# Evaluation Metrics:
# R2: 0.677476134873436
# MAE: 23.6447
# MSE: 1127.7816
# RMSE: 33.5825
# R2: 0.6775
# MAPE: 0.0107
# sMAPE: 0.0107
#
#
# ISLA: Lanzarote, WINDOW = 14
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @132353857102416
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @132353952340240
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @132353726048848
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @132353726051152
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @132353726052112
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @132353726053328
# Evaluation Metrics:
# R2: 0.6808776361722852
# MAE: 22.9176
# MSE: 1115.8875
# RMSE: 33.4049
# R2: 0.6809
# MAPE: 0.0103
# sMAPE: 0.0103
#
#
# ISLA: Lanzarote, WINDOW = 15
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @132353727900176
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @132353857013328
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @132353726042320
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @132353726038800
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @132353726042704
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @132353726039696
# Evaluation Metrics:
# R2: 0.6388975951285811
# MAE: 24.0942
# MSE: 1262.6807
# RMSE: 35.5342
# R2: 0.6389
# MAPE: 0.0108
# sMAPE: 0.0109
#
#
# ISLA: Lanzarote, WINDOW = 16
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @132353725875600
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @132353725875792
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @132353726045008
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @132353726050064
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @132353726052176
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @132353726040208
# Evaluation Metrics:
# R2: 0.6532598643216606
# MAE: 23.4822
# MSE: 1212.4596
# RMSE: 34.8204
# R2: 0.6533
# MAPE: 0.0106
# sMAPE: 0.0106
#
#
# ISLA: Lanzarote, WINDOW = 17
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @132353725890000
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @132353952340240
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @132353726042320
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @132353726038800
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @132353726042704
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @132353726039696
# Evaluation Metrics:
# R2: 0.6387155110342881
# MAE: 25.4684
# MSE: 1263.3174
# RMSE: 35.5432
# R2: 0.6387
# MAPE: 0.0115
# sMAPE: 0.0115
#
#
# ISLA: Lanzarote, WINDOW = 18
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @132353725908944
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @132353727900176
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @132353726038160
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @132353726044624
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @132353726041104
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @132353726049168
# Evaluation Metrics:
# R2: 0.659572792480652
# MAE: 22.4998
# MSE: 1190.3849
# RMSE: 34.5020
# R2: 0.6596
# MAPE: 0.0102
# sMAPE: 0.0101
#
#
# ISLA: Lanzarote, WINDOW = 19
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @132353857102416
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @132353725875600
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @132353726039120
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @132353726041808
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @132353726050832
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @132353726043216
# Evaluation Metrics:
# R2: 0.6646257973930991
# MAE: 23.1922
# MSE: 1172.7159
# RMSE: 34.2449
# R2: 0.6646
# MAPE: 0.0105
# sMAPE: 0.0105
#
#
# ISLA: Fuerteventura, WINDOW = 5
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @132353725877776
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @132353725889232
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @132353725915856
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @132353725909136
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @132353725920272
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @132353725912016
# Evaluation Metrics:
# R2: 0.4947313578873527
# MAE: 24.5474
# MSE: 1183.3140
# RMSE: 34.3993
# R2: 0.4947
# MAPE: 0.0145
# sMAPE: 0.0145
#
#
# ISLA: Fuerteventura, WINDOW = 6
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @132353726040336
# ...
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @132353725878992
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @132353726514000
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @132353726513232
# Evaluation Metrics:
# R2: 0.060901419349912334
# MAE: 5.8350
# MSE: 54.7653
# RMSE: 7.4004
# R2: 0.0609
# MAPE: 0.0342
# sMAPE: 0.0340
#
#
# ISLA: El Hierro, WINDOW = 5
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @132353857076304
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @132353881787536
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=5, forecast_length=1, share_thetas=False) at @132353725914960
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @132353725921040
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @132353725922768
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=5, forecast_length=1, share_thetas=False) at @132353726518800
# Evaluation Metrics:
# R2: 0.09496667444058804
# MAE: 3.1677
# MSE: 17.6563
# RMSE: 4.2019
# R2: 0.0950
# MAPE: 0.0241
# sMAPE: 0.0241
#
#
# ISLA: El Hierro, WINDOW = 6
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @132353726053840
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @132353726040144
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=6, forecast_length=1, share_thetas=False) at @132353725915472
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @132353726517712
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @132353726516560
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=6, forecast_length=1, share_thetas=False) at @132353726519760
# Evaluation Metrics:
# R2: 0.16691596982715573
# MAE: 3.0303
# MSE: 16.2527
# RMSE: 4.0315
# R2: 0.1669
# MAPE: 0.0231
# sMAPE: 0.0230
#
#
# ISLA: El Hierro, WINDOW = 7
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @132353727904848
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @132353725877776
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=7, forecast_length=1, share_thetas=False) at @132353726048592
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @132353726042640
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @132353726520208
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=7, forecast_length=1, share_thetas=False) at @132353726515984
# Evaluation Metrics:
# R2: 0.17576030180961533
# MAE: 3.0083
# MSE: 16.0801
# RMSE: 4.0100
# R2: 0.1758
# MAPE: 0.0229
# sMAPE: 0.0228
#
#
# ISLA: El Hierro, WINDOW = 8
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @132353727898192
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @132353726044432
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=8, forecast_length=1, share_thetas=False) at @132353857076432
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @132353725918160
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @132353726516560
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=8, forecast_length=1, share_thetas=False) at @132353726519760
# Evaluation Metrics:
# R2: 0.21556561326209522
# MAE: 2.9173
# MSE: 15.3036
# RMSE: 3.9120
# R2: 0.2156
# MAPE: 0.0222
# sMAPE: 0.0221
#
#
# ISLA: El Hierro, WINDOW = 9
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @132353881898448
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @132353881790736
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=9, forecast_length=1, share_thetas=False) at @132353726038224
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @132353726049232
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @132353726513552
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=9, forecast_length=1, share_thetas=False) at @132353726519824
# Evaluation Metrics:
# R2: 0.2277581881357965
# MAE: 2.8848
# MSE: 15.0657
# RMSE: 3.8815
# R2: 0.2278
# MAPE: 0.0220
# sMAPE: 0.0219
#
#
# ISLA: El Hierro, WINDOW = 10
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @132353726044432
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @132353725890000
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=10, forecast_length=1, share_thetas=False) at @132353725878992
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @132353725890320
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @132353726519376
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=10, forecast_length=1, share_thetas=False) at @132353726516304
# Evaluation Metrics:
# R2: 0.209243916133245
# MAE: 2.9590
# MSE: 15.4269
# RMSE: 3.9277
# R2: 0.2092
# MAPE: 0.0225
# sMAPE: 0.0225
#
#
# ISLA: El Hierro, WINDOW = 11
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @132353726053072
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @132353727898192
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=11, forecast_length=1, share_thetas=False) at @132353725923216
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @132353725910672
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @132353726516240
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=11, forecast_length=1, share_thetas=False) at @132353726519696
# Evaluation Metrics:
# R2: 0.21839295633108213
# MAE: 2.9062
# MSE: 15.2484
# RMSE: 3.9049
# R2: 0.2184
# MAPE: 0.0221
# sMAPE: 0.0221
#
#
# ISLA: El Hierro, WINDOW = 12
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @132353726039568
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @132353726044112
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=12, forecast_length=1, share_thetas=False) at @132353725882320
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @132353725889552
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @132353726513488
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=12, forecast_length=1, share_thetas=False) at @132353726516560
# Evaluation Metrics:
# R2: 0.1942475924678445
# MAE: 2.9410
# MSE: 15.7195
# RMSE: 3.9648
# R2: 0.1942
# MAPE: 0.0224
# sMAPE: 0.0223
#
#
# ISLA: El Hierro, WINDOW = 13
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @132353857013136
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @132353726044432
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=13, forecast_length=1, share_thetas=False) at @132353725919568
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @132353725909776
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @132353726518864
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=13, forecast_length=1, share_thetas=False) at @132353726521680
# Evaluation Metrics:
# R2: 0.2242501339459262
# MAE: 2.8965
# MSE: 15.1341
# RMSE: 3.8903
# R2: 0.2243
# MAPE: 0.0220
# sMAPE: 0.0220
#
#
# ISLA: El Hierro, WINDOW = 14
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @132353727898192
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @132354048778576
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=14, forecast_length=1, share_thetas=False) at @132353725890320
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @132353725875600
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @132353726513680
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=14, forecast_length=1, share_thetas=False) at @132353726514192
# Evaluation Metrics:
# R2: 0.21701776207728052
# MAE: 2.9053
# MSE: 15.2752
# RMSE: 3.9084
# R2: 0.2170
# MAPE: 0.0221
# sMAPE: 0.0220
#
#
# ISLA: El Hierro, WINDOW = 15
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @132353727891088
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @132353725880592
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=15, forecast_length=1, share_thetas=False) at @132353725909072
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @132353881898192
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @132353726521616
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=15, forecast_length=1, share_thetas=False) at @132353726517968
# Evaluation Metrics:
# R2: 0.2300292886869728
# MAE: 2.8478
# MSE: 15.0214
# RMSE: 3.8757
# R2: 0.2300
# MAPE: 0.0217
# sMAPE: 0.0216
#
#
# ISLA: El Hierro, WINDOW = 16
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @132353725908368
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @132353725912464
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=16, forecast_length=1, share_thetas=False) at @132353725886160
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @132353727904848
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @132353726516368
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=16, forecast_length=1, share_thetas=False) at @132353726514640
# Evaluation Metrics:
# R2: 0.17968759087358843
# MAE: 3.0279
# MSE: 16.0035
# RMSE: 4.0004
# R2: 0.1797
# MAPE: 0.0230
# sMAPE: 0.0230
#
#
# ISLA: El Hierro, WINDOW = 17
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @132353857013328
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @132353725876176
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=17, forecast_length=1, share_thetas=False) at @132353726053968
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @132353726043088
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @132353726520848
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=17, forecast_length=1, share_thetas=False) at @132353726515536
# Evaluation Metrics:
# R2: 0.2224989761071967
# MAE: 2.9278
# MSE: 15.1683
# RMSE: 3.8947
# R2: 0.2225
# MAPE: 0.0223
# sMAPE: 0.0222
#
#
# ISLA: El Hierro, WINDOW = 18
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @132353725922000
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @132353857076304
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=18, forecast_length=1, share_thetas=False) at @132353726040080
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @132353726040976
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @132353726514960
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=18, forecast_length=1, share_thetas=False) at @132353726520528
# Evaluation Metrics:
# R2: 0.22541956517556805
# MAE: 2.9202
# MSE: 15.1113
# RMSE: 3.8873
# R2: 0.2254
# MAPE: 0.0222
# sMAPE: 0.0222
#
#
# ISLA: El Hierro, WINDOW = 19
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @132353725908368
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @132353857076432
#      | -- GenericBlock(units=128, thetas_dim=4, backcast_length=19, forecast_length=1, share_thetas=False) at @132353726049424
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @132353857089744
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @132353726520784
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=19, forecast_length=1, share_thetas=False) at @132353726513616
# Evaluation Metrics:
# R2: 0.24654866894346927
# MAE: 2.8745
# MSE: 14.6991
# RMSE: 3.8339
# R2: 0.2465
# MAPE: 0.0219
# sMAPE: 0.0218

# %%
for isla in islas:
    print(f'\n\nBest window for {isla}: {windows[np.argmax(results[isla])]}')
# Out:
# Best window for Tenerife: 9
#
#
# Best window for Gran Canaria: 11
#
#
# Best window for Lanzarote: 11
#
#
# Best window for Fuerteventura: 8
#
#
# Best window for La Palma: 7
#
#
# Best window for La Gomera: 6
#
#
# Best window for El Hierro: 19
